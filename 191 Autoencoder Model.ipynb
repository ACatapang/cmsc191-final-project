# %% [markdown]
# ## Importing Libraries
# We have the following:
# *   numpy is imported as np for numerical operations.
# *   matplotlib.pyplot is imported as plt for plotting.
# *   Importing specific layers and models from Keras for building and training neural networks.
# *   Importing the MNIST dataset from Keras, a dataset of handwritten digits.

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow_datasets as tfds
import tensorflow as tf
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist
from tensorflow.keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
import time
import cv2

# %% [markdown]
# ## Importing dataset from Google Drive

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory="/content/drive/Shareddrives/CMSC 191/CMSC 191 GenAI Datasets",
    labels='inferred',
    label_mode='categorical',
    batch_size=7,
    image_size=(30, 40))

print(train_ds)
# Out:
# Found 1620 files belonging to 1 classes.
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 30, 40, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>

# %% [markdown]
# ## Loading and Normalizing MNIST Data
# Loading the MNIST dataset into training and testing sets.
# Normalizing pixel values to be in the range [0, 1] by dividing by 255.0.

# %%
ds_numpy = tfds.as_numpy(train_ds)

# Extract images and labels into separate lists
images = []
labels = []
for image_batch, label_batch in ds_numpy:
    images.extend(image_batch)
    labels.extend(label_batch)

# Convert the lists to NumPy arrays
x_train = np.array(images)
y_train = np.array(labels)


x_train, x_test, y_train, y_test = train_test_split(
    x_train, y_train, test_size=0.3, random_state=42  # Adjust test_size and random_state as needed
)

# Normalize pixel values
x_train = x_train.astype('float32') / 255.0

# 2. Normalize x_test (if you haven't already normalized x_train)
x_test = x_test.astype('float32') / 255.0

# %% [markdown]
# ## Flattening the Images
# Flattening the 28x28 images into 1D arrays of length 784.

# %%
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %% [markdown]
# ## Defining the Autoencoder Model
# Defining a simple autoencoder architecture with three encoding layers and three corresponding decoding layers.
# Using ReLU activation for encoding layers and sigmoid activation for the final decoding layer.
# Compiling the model with the Adam optimizer and binary cross-entropy loss.

# %%
input_img = Input(shape=(3600,))
encoded = Dense(256, activation='relu')(input_img)  # Added layer
encoded = Dense(128, activation='relu')(encoded)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)  # Added layer

decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(256, activation='relu')(decoded)  # Added layer
decoded = Dense(3600, activation='sigmoid')(decoded)  # Added layer

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# ## Training the Autoencoder
# Training the autoencoder using the training data (x_train) for both input and target.
# Training for 50 epochs with a batch size of 256 and shuffling the training data.
# Using the validation data (x_test) for validation during training.

# %%
start_time = time.time()

autoencoder.fit(x_train, x_train, epochs=512, batch_size=14, shuffle=True, validation_data=(x_test, x_test))

end_time = time.time()

training_time = end_time - start_time

print(f"Training time: {training_time} seconds")
# Out:
# Epoch 1/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4052 - val_loss: 0.4212
# Epoch 2/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4010 - val_loss: 0.4211
# Epoch 3/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4107 - val_loss: 0.4209
# Epoch 4/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4050 - val_loss: 0.4209
# Epoch 5/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4046 - val_loss: 0.4209
# Epoch 6/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4086 - val_loss: 0.4209
# Epoch 7/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.4099 - val_loss: 0.4208
# Epoch 8/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.4039 - val_loss: 0.4209
# Epoch 9/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4045 - val_loss: 0.4208
# Epoch 10/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4047 - val_loss: 0.4208
# Epoch 11/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4110 - val_loss: 0.4208
# Epoch 12/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4093 - val_loss: 0.4209
# Epoch 13/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4085 - val_loss: 0.4211
# Epoch 14/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.4058 - val_loss: 0.4209
# Epoch 15/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4055 - val_loss: 0.4210
# Epoch 16/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.4041 - val_loss: 0.4210
# Epoch 17/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4086 - val_loss: 0.4208
# Epoch 18/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4082 - val_loss: 0.4210
# Epoch 19/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4071 - val_loss: 0.4209
# Epoch 20/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4058 - val_loss: 0.4209
# Epoch 21/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4029 - val_loss: 0.4209
# Epoch 22/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4056 - val_loss: 0.4209
# Epoch 23/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4093 - val_loss: 0.4209
# Epoch 24/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4078 - val_loss: 0.4209
# Epoch 25/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4036 - val_loss: 0.4209
# Epoch 26/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4040 - val_loss: 0.4208
# Epoch 27/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4081 - val_loss: 0.4209
# Epoch 28/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4086 - val_loss: 0.4209
# Epoch 29/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4072 - val_loss: 0.4209
# Epoch 30/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4060 - val_loss: 0.4209
# Epoch 31/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4101 - val_loss: 0.4209
# Epoch 32/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4080 - val_loss: 0.4209
# Epoch 33/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.4087 - val_loss: 0.4209
# Epoch 34/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4104 - val_loss: 0.4210
# Epoch 35/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4087 - val_loss: 0.4215
# Epoch 36/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4038 - val_loss: 0.4210
# Epoch 37/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4085 - val_loss: 0.4211
# Epoch 38/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4095 - val_loss: 0.4212
# Epoch 39/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.4056 - val_loss: 0.4209
# Epoch 40/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4058 - val_loss: 0.4209
# Epoch 41/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4112 - val_loss: 0.4209
# Epoch 42/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4051 - val_loss: 0.4209
# Epoch 43/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4093 - val_loss: 0.4209
# Epoch 44/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4097 - val_loss: 0.4209
# Epoch 45/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4067 - val_loss: 0.4209
# Epoch 46/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4084 - val_loss: 0.4210
# Epoch 47/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4100 - val_loss: 0.4210
# Epoch 48/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4098 - val_loss: 0.4209
# Epoch 49/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4081 - val_loss: 0.4209
# Epoch 50/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4068 - val_loss: 0.4209
# Epoch 51/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4082 - val_loss: 0.4209
# Epoch 52/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4131 - val_loss: 0.4209
# Epoch 53/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4024 - val_loss: 0.4213
# Epoch 54/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4060 - val_loss: 0.4209
# Epoch 55/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4074 - val_loss: 0.4210
# Epoch 56/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4112 - val_loss: 0.4210
# Epoch 57/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4067 - val_loss: 0.4209
# Epoch 58/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4088 - val_loss: 0.4208
# Epoch 59/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4043 - val_loss: 0.4209
# Epoch 60/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4118 - val_loss: 0.4210
# Epoch 61/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4075 - val_loss: 0.4209
# Epoch 62/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4093 - val_loss: 0.4209
# Epoch 63/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4086 - val_loss: 0.4209
# Epoch 64/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4085 - val_loss: 0.4210
# Epoch 65/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4037 - val_loss: 0.4210
# Epoch 66/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4111 - val_loss: 0.4209
# Epoch 67/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4078 - val_loss: 0.4209
# Epoch 68/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4097 - val_loss: 0.4210
# Epoch 69/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4083 - val_loss: 0.4210
# Epoch 70/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4092 - val_loss: 0.4210
# Epoch 71/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4027 - val_loss: 0.4210
# Epoch 72/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4098 - val_loss: 0.4210
# Epoch 73/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4030 - val_loss: 0.4209
# Epoch 74/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4075 - val_loss: 0.4210
# Epoch 75/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4100 - val_loss: 0.4210
# Epoch 76/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4055 - val_loss: 0.4209
# Epoch 77/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.4077 - val_loss: 0.4210
# Epoch 78/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4040 - val_loss: 0.4210
# Epoch 79/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4053 - val_loss: 0.4210
# Epoch 80/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4073 - val_loss: 0.4209
# Epoch 81/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.4101 - val_loss: 0.4211
# Epoch 82/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4095 - val_loss: 0.4210
# Epoch 83/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4081 - val_loss: 0.4211
# Epoch 84/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4047 - val_loss: 0.4211
# Epoch 85/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4021 - val_loss: 0.4211
# Epoch 86/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4085 - val_loss: 0.4214
# Epoch 87/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4114 - val_loss: 0.4212
# Epoch 88/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4034 - val_loss: 0.4211
# Epoch 89/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4091 - val_loss: 0.4210
# Epoch 90/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4115 - val_loss: 0.4210
# Epoch 91/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.4093 - val_loss: 0.4210
# Epoch 92/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4030 - val_loss: 0.4209
# Epoch 93/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4095 - val_loss: 0.4209
# Epoch 94/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4049 - val_loss: 0.4210
# Epoch 95/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4072 - val_loss: 0.4210
# Epoch 96/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4073 - val_loss: 0.4210
# Epoch 97/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4119 - val_loss: 0.4211
# Epoch 98/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4069 - val_loss: 0.4209
# Epoch 99/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4050 - val_loss: 0.4210
# Epoch 100/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4084 - val_loss: 0.4209
# Epoch 101/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4063 - val_loss: 0.4209
# Epoch 102/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4033 - val_loss: 0.4209
# Epoch 103/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4084 - val_loss: 0.4210
# Epoch 104/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4097 - val_loss: 0.4209
# Epoch 105/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4027 - val_loss: 0.4210
# Epoch 106/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4076 - val_loss: 0.4211
# Epoch 107/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4080 - val_loss: 0.4210
# Epoch 108/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4111 - val_loss: 0.4211
# Epoch 109/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4052 - val_loss: 0.4210
# Epoch 110/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4085 - val_loss: 0.4212
# Epoch 111/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4060 - val_loss: 0.4210
# Epoch 112/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4083 - val_loss: 0.4209
# Epoch 113/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.4050 - val_loss: 0.4209
# Epoch 114/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4076 - val_loss: 0.4210
# Epoch 115/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4093 - val_loss: 0.4210
# Epoch 116/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4091 - val_loss: 0.4210
# Epoch 117/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4036 - val_loss: 0.4209
# Epoch 118/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4012 - val_loss: 0.4211
# Epoch 119/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4031 - val_loss: 0.4212
# Epoch 120/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.4067 - val_loss: 0.4212
# Epoch 121/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 0.4102 - val_loss: 0.4214
# Epoch 122/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4104 - val_loss: 0.4211
# Epoch 123/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4075 - val_loss: 0.4210
# Epoch 124/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4070 - val_loss: 0.4209
# Epoch 125/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4106 - val_loss: 0.4209
# Epoch 126/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.4089 - val_loss: 0.4210
# Epoch 127/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4087 - val_loss: 0.4209
# Epoch 128/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4030 - val_loss: 0.4209
# Epoch 129/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4043 - val_loss: 0.4209
# Epoch 130/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4066 - val_loss: 0.4210
# Epoch 131/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4080 - val_loss: 0.4209
# Epoch 132/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4054 - val_loss: 0.4209
# Epoch 133/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4034 - val_loss: 0.4209
# Epoch 134/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4073 - val_loss: 0.4210
# Epoch 135/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4080 - val_loss: 0.4210
# Epoch 136/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4056 - val_loss: 0.4210
# Epoch 137/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4161 - val_loss: 0.4210
# Epoch 138/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4060 - val_loss: 0.4211
# Epoch 139/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4083 - val_loss: 0.4211
# Epoch 140/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4072 - val_loss: 0.4211
# Epoch 141/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4067 - val_loss: 0.4209
# Epoch 142/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4085 - val_loss: 0.4214
# Epoch 143/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4102 - val_loss: 0.4210
# Epoch 144/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4093 - val_loss: 0.4209
# Epoch 145/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4086 - val_loss: 0.4210
# Epoch 146/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4090 - val_loss: 0.4210
# Epoch 147/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4124 - val_loss: 0.4210
# Epoch 148/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4047 - val_loss: 0.4210
# Epoch 149/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4073 - val_loss: 0.4209
# Epoch 150/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4089 - val_loss: 0.4211
# Epoch 151/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4080 - val_loss: 0.4210
# Epoch 152/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4047 - val_loss: 0.4210
# Epoch 153/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4051 - val_loss: 0.4210
# Epoch 154/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4030 - val_loss: 0.4211
# Epoch 155/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4077 - val_loss: 0.4210
# Epoch 156/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4056 - val_loss: 0.4211
# Epoch 157/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4072 - val_loss: 0.4211
# Epoch 158/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4031 - val_loss: 0.4210
# Epoch 159/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4076 - val_loss: 0.4211
# Epoch 160/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4062 - val_loss: 0.4213
# Epoch 161/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4102 - val_loss: 0.4212
# Epoch 162/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4131 - val_loss: 0.4210
# Epoch 163/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4028 - val_loss: 0.4210
# Epoch 164/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4071 - val_loss: 0.4212
# Epoch 165/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4059 - val_loss: 0.4217
# Epoch 166/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4103 - val_loss: 0.4211
# Epoch 167/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4064 - val_loss: 0.4208
# Epoch 168/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4088 - val_loss: 0.4209
# Epoch 169/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4095 - val_loss: 0.4209
# Epoch 170/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4031 - val_loss: 0.4210
# Epoch 171/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4023 - val_loss: 0.4209
# Epoch 172/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4100 - val_loss: 0.4209
# Epoch 173/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4033 - val_loss: 0.4210
# Epoch 174/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4078 - val_loss: 0.4209
# Epoch 175/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4083 - val_loss: 0.4210
# Epoch 176/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4114 - val_loss: 0.4210
# Epoch 177/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4065 - val_loss: 0.4209
# Epoch 178/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4072 - val_loss: 0.4210
# Epoch 179/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4049 - val_loss: 0.4209
# Epoch 180/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4102 - val_loss: 0.4210
# Epoch 181/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4076 - val_loss: 0.4211
# Epoch 182/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4129 - val_loss: 0.4211
# Epoch 183/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4087 - val_loss: 0.4213
# Epoch 184/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4076 - val_loss: 0.4211
# Epoch 185/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4089 - val_loss: 0.4210
# Epoch 186/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4054 - val_loss: 0.4212
# Epoch 187/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4073 - val_loss: 0.4211
# Epoch 188/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4084 - val_loss: 0.4211
# Epoch 189/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4159 - val_loss: 0.4210
# Epoch 190/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4053 - val_loss: 0.4212
# Epoch 191/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4083 - val_loss: 0.4211
# Epoch 192/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4082 - val_loss: 0.4210
# Epoch 193/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4130 - val_loss: 0.4210
# Epoch 194/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4086 - val_loss: 0.4210
# Epoch 195/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.4075 - val_loss: 0.4210
# Epoch 196/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4094 - val_loss: 0.4210
# Epoch 197/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4002 - val_loss: 0.4210
# Epoch 198/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4073 - val_loss: 0.4209
# Epoch 199/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4057 - val_loss: 0.4211
# Epoch 200/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4055 - val_loss: 0.4211
# Epoch 201/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4082 - val_loss: 0.4211
# Epoch 202/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4079 - val_loss: 0.4210
# Epoch 203/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4076 - val_loss: 0.4209
# Epoch 204/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4095 - val_loss: 0.4211
# Epoch 205/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4059 - val_loss: 0.4211
# Epoch 206/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4110 - val_loss: 0.4211
# Epoch 207/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4075 - val_loss: 0.4213
# Epoch 208/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4019 - val_loss: 0.4209
# Epoch 209/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4019 - val_loss: 0.4211
# Epoch 210/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4095 - val_loss: 0.4211
# Epoch 211/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4095 - val_loss: 0.4210
# Epoch 212/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4128 - val_loss: 0.4210
# Epoch 213/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4106 - val_loss: 0.4210
# Epoch 214/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4066 - val_loss: 0.4210
# Epoch 215/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4054 - val_loss: 0.4210
# Epoch 216/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4012 - val_loss: 0.4212
# Epoch 217/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4081 - val_loss: 0.4212
# Epoch 218/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4001 - val_loss: 0.4211
# Epoch 219/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4046 - val_loss: 0.4211
# Epoch 220/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4055 - val_loss: 0.4210
# Epoch 221/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4125 - val_loss: 0.4209
# Epoch 222/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4110 - val_loss: 0.4211
# Epoch 223/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4063 - val_loss: 0.4211
# Epoch 224/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4060 - val_loss: 0.4212
# Epoch 225/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4105 - val_loss: 0.4210
# Epoch 226/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4089 - val_loss: 0.4210
# Epoch 227/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.4123 - val_loss: 0.4210
# Epoch 228/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4091 - val_loss: 0.4209
# Epoch 229/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4013 - val_loss: 0.4212
# Epoch 230/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4111 - val_loss: 0.4210
# Epoch 231/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4118 - val_loss: 0.4211
# Epoch 232/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4020 - val_loss: 0.4211
# Epoch 233/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4049 - val_loss: 0.4211
# Epoch 234/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4066 - val_loss: 0.4212
# Epoch 235/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4115 - val_loss: 0.4210
# Epoch 236/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4096 - val_loss: 0.4211
# Epoch 237/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.4090 - val_loss: 0.4211
# Epoch 238/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4074 - val_loss: 0.4210
# Epoch 239/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4073 - val_loss: 0.4210
# Epoch 240/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4019 - val_loss: 0.4210
# Epoch 241/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4079 - val_loss: 0.4210
# Epoch 242/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4072 - val_loss: 0.4211
# Epoch 243/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4047 - val_loss: 0.4211
# Epoch 244/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4094 - val_loss: 0.4211
# Epoch 245/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4033 - val_loss: 0.4210
# Epoch 246/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4093 - val_loss: 0.4211
# Epoch 247/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4037 - val_loss: 0.4216
# Epoch 248/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4104 - val_loss: 0.4213
# Epoch 249/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4062 - val_loss: 0.4209
# Epoch 250/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4072 - val_loss: 0.4212
# Epoch 251/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.4076 - val_loss: 0.4210
# Epoch 252/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4023 - val_loss: 0.4210
# Epoch 253/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4117 - val_loss: 0.4211
# Epoch 254/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4107 - val_loss: 0.4210
# Epoch 255/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4086 - val_loss: 0.4210
# Epoch 256/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4063 - val_loss: 0.4210
# Epoch 257/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.4094 - val_loss: 0.4211
# Epoch 258/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4073 - val_loss: 0.4211
# Epoch 259/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4116 - val_loss: 0.4212
# Epoch 260/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4052 - val_loss: 0.4213
# Epoch 261/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4042 - val_loss: 0.4211
# Epoch 262/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4049 - val_loss: 0.4209
# Epoch 263/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4065 - val_loss: 0.4209
# Epoch 264/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4136 - val_loss: 0.4210
# Epoch 265/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4110 - val_loss: 0.4210
# Epoch 266/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.4137 - val_loss: 0.4210
# Epoch 267/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4102 - val_loss: 0.4209
# Epoch 268/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.4075 - val_loss: 0.4210
# Epoch 269/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4094 - val_loss: 0.4210
# Epoch 270/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4060 - val_loss: 0.4210
# Epoch 271/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4037 - val_loss: 0.4210
# Epoch 272/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4037 - val_loss: 0.4210
# Epoch 273/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4085 - val_loss: 0.4211
# Epoch 274/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4032 - val_loss: 0.4210
# Epoch 275/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4068 - val_loss: 0.4210
# Epoch 276/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4047 - val_loss: 0.4211
# Epoch 277/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4059 - val_loss: 0.4212
# Epoch 278/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4045 - val_loss: 0.4210
# Epoch 279/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.4093 - val_loss: 0.4211
# Epoch 280/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4090 - val_loss: 0.4211
# Epoch 281/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4081 - val_loss: 0.4211
# Epoch 282/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4097 - val_loss: 0.4209
# Epoch 283/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4101 - val_loss: 0.4210
# Epoch 284/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4040 - val_loss: 0.4211
# Epoch 285/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4031 - val_loss: 0.4209
# Epoch 286/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.3979 - val_loss: 0.4210
# Epoch 287/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4081 - val_loss: 0.4210
# Epoch 288/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4078 - val_loss: 0.4210
# Epoch 289/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4072 - val_loss: 0.4211
# Epoch 290/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4078 - val_loss: 0.4211
# Epoch 291/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4044 - val_loss: 0.4211
# Epoch 292/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4095 - val_loss: 0.4210
# Epoch 293/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4107 - val_loss: 0.4211
# Epoch 294/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4061 - val_loss: 0.4212
# Epoch 295/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4108 - val_loss: 0.4212
# Epoch 296/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.4135 - val_loss: 0.4213
# Epoch 297/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4035 - val_loss: 0.4215
# Epoch 298/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4067 - val_loss: 0.4219
# Epoch 299/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4052 - val_loss: 0.4210
# Epoch 300/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4077 - val_loss: 0.4209
# Epoch 301/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4062 - val_loss: 0.4209
# Epoch 302/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4102 - val_loss: 0.4208
# Epoch 303/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4078 - val_loss: 0.4209
# Epoch 304/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4072 - val_loss: 0.4208
# Epoch 305/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4076 - val_loss: 0.4208
# Epoch 306/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4032 - val_loss: 0.4209
# Epoch 307/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4070 - val_loss: 0.4209
# Epoch 308/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4063 - val_loss: 0.4209
# Epoch 309/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4062 - val_loss: 0.4209
# Epoch 310/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4084 - val_loss: 0.4209
# Epoch 311/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4079 - val_loss: 0.4209
# Epoch 312/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - loss: 0.4020 - val_loss: 0.4209
# Epoch 313/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4091 - val_loss: 0.4208
# Epoch 314/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.4021 - val_loss: 0.4209
# Epoch 315/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4081 - val_loss: 0.4209
# Epoch 316/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4075 - val_loss: 0.4209
# Epoch 317/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4095 - val_loss: 0.4211
# Epoch 318/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4116 - val_loss: 0.4210
# Epoch 319/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4052 - val_loss: 0.4210
# Epoch 320/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4073 - val_loss: 0.4211
# Epoch 321/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4025 - val_loss: 0.4212
# Epoch 322/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.4075 - val_loss: 0.4211
# Epoch 323/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4089 - val_loss: 0.4211
# Epoch 324/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4111 - val_loss: 0.4210
# Epoch 325/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4058 - val_loss: 0.4211
# Epoch 326/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4081 - val_loss: 0.4211
# Epoch 327/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4062 - val_loss: 0.4210
# Epoch 328/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4084 - val_loss: 0.4209
# Epoch 329/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4104 - val_loss: 0.4209
# Epoch 330/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4085 - val_loss: 0.4210
# Epoch 331/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4122 - val_loss: 0.4211
# Epoch 332/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4066 - val_loss: 0.4211
# Epoch 333/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4080 - val_loss: 0.4210
# Epoch 334/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4100 - val_loss: 0.4210
# Epoch 335/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4074 - val_loss: 0.4211
# Epoch 336/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4030 - val_loss: 0.4210
# Epoch 337/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4041 - val_loss: 0.4213
# Epoch 338/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4074 - val_loss: 0.4210
# Epoch 339/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4043 - val_loss: 0.4215
# Epoch 340/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4080 - val_loss: 0.4213
# Epoch 341/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.4019 - val_loss: 0.4211
# Epoch 342/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4082 - val_loss: 0.4210
# Epoch 343/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4059 - val_loss: 0.4209
# Epoch 344/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4063 - val_loss: 0.4210
# Epoch 345/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4103 - val_loss: 0.4210
# Epoch 346/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.4062 - val_loss: 0.4209
# Epoch 347/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4068 - val_loss: 0.4210
# Epoch 348/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4002 - val_loss: 0.4210
# Epoch 349/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4086 - val_loss: 0.4210
# Epoch 350/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4030 - val_loss: 0.4211
# Epoch 351/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4093 - val_loss: 0.4210
# Epoch 352/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4089 - val_loss: 0.4211
# Epoch 353/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4095 - val_loss: 0.4210
# Epoch 354/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4112 - val_loss: 0.4211
# Epoch 355/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4035 - val_loss: 0.4210
# Epoch 356/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.4052 - val_loss: 0.4213
# Epoch 357/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.4071 - val_loss: 0.4212
# Epoch 358/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4083 - val_loss: 0.4213
# Epoch 359/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4109 - val_loss: 0.4210
# Epoch 360/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4108 - val_loss: 0.4211
# Epoch 361/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4106 - val_loss: 0.4212
# Epoch 362/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4046 - val_loss: 0.4210
# Epoch 363/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4090 - val_loss: 0.4211
# Epoch 364/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4158 - val_loss: 0.4211
# Epoch 365/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4048 - val_loss: 0.4212
# Epoch 366/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4056 - val_loss: 0.4211
# Epoch 367/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4116 - val_loss: 0.4212
# Epoch 368/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.4131 - val_loss: 0.4212
# Epoch 369/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4068 - val_loss: 0.4214
# Epoch 370/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4038 - val_loss: 0.4215
# Epoch 371/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4059 - val_loss: 0.4211
# Epoch 372/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4060 - val_loss: 0.4210
# Epoch 373/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4062 - val_loss: 0.4210
# Epoch 374/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4064 - val_loss: 0.4210
# Epoch 375/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4068 - val_loss: 0.4210
# Epoch 376/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4079 - val_loss: 0.4210
# Epoch 377/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.4098 - val_loss: 0.4212
# Epoch 378/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4110 - val_loss: 0.4211
# Epoch 379/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4089 - val_loss: 0.4213
# Epoch 380/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4040 - val_loss: 0.4212
# Epoch 381/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4096 - val_loss: 0.4211
# Epoch 382/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4110 - val_loss: 0.4210
# Epoch 383/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4142 - val_loss: 0.4210
# Epoch 384/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4021 - val_loss: 0.4210
# Epoch 385/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4048 - val_loss: 0.4209
# Epoch 386/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4089 - val_loss: 0.4209
# Epoch 387/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.4116 - val_loss: 0.4210
# Epoch 388/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4061 - val_loss: 0.4209
# Epoch 389/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.4108 - val_loss: 0.4209
# Epoch 390/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4032 - val_loss: 0.4210
# Epoch 391/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4011 - val_loss: 0.4212
# Epoch 392/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4049 - val_loss: 0.4210
# Epoch 393/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4081 - val_loss: 0.4211
# Epoch 394/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4036 - val_loss: 0.4211
# Epoch 395/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4067 - val_loss: 0.4210
# Epoch 396/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4042 - val_loss: 0.4210
# Epoch 397/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4061 - val_loss: 0.4210
# Epoch 398/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4042 - val_loss: 0.4210
# Epoch 399/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4067 - val_loss: 0.4209
# Epoch 400/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4037 - val_loss: 0.4210
# Epoch 401/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4080 - val_loss: 0.4209
# Epoch 402/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4070 - val_loss: 0.4213
# Epoch 403/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4062 - val_loss: 0.4211
# Epoch 404/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4091 - val_loss: 0.4210
# Epoch 405/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4042 - val_loss: 0.4211
# Epoch 406/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4088 - val_loss: 0.4210
# Epoch 407/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4059 - val_loss: 0.4209
# Epoch 408/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4052 - val_loss: 0.4210
# Epoch 409/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4050 - val_loss: 0.4211
# Epoch 410/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.4155 - val_loss: 0.4211
# Epoch 411/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4046 - val_loss: 0.4210
# Epoch 412/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4110 - val_loss: 0.4211
# Epoch 413/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4136 - val_loss: 0.4210
# Epoch 414/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4109 - val_loss: 0.4212
# Epoch 415/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4089 - val_loss: 0.4211
# Epoch 416/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4039 - val_loss: 0.4316
# Epoch 417/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4201 - val_loss: 0.4231
# Epoch 418/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4156 - val_loss: 0.4212
# Epoch 419/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4100 - val_loss: 0.4214
# Epoch 420/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.4121 - val_loss: 0.4209
# Epoch 421/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4020 - val_loss: 0.4210
# Epoch 422/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4061 - val_loss: 0.4209
# Epoch 423/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4095 - val_loss: 0.4210
# Epoch 424/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4078 - val_loss: 0.4208
# Epoch 425/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4071 - val_loss: 0.4208
# Epoch 426/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4103 - val_loss: 0.4208
# Epoch 427/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4058 - val_loss: 0.4208
# Epoch 428/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4135 - val_loss: 0.4209
# Epoch 429/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4157 - val_loss: 0.4208
# Epoch 430/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4078 - val_loss: 0.4209
# Epoch 431/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4049 - val_loss: 0.4209
# Epoch 432/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4085 - val_loss: 0.4209
# Epoch 433/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4088 - val_loss: 0.4209
# Epoch 434/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4055 - val_loss: 0.4209
# Epoch 435/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4078 - val_loss: 0.4209
# Epoch 436/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4086 - val_loss: 0.4208
# Epoch 437/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4142 - val_loss: 0.4209
# Epoch 438/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4081 - val_loss: 0.4209
# Epoch 439/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4083 - val_loss: 0.4210
# Epoch 440/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4027 - val_loss: 0.4210
# Epoch 441/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4053 - val_loss: 0.4210
# Epoch 442/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4120 - val_loss: 0.4210
# Epoch 443/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4103 - val_loss: 0.4210
# Epoch 444/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4061 - val_loss: 0.4210
# Epoch 445/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4092 - val_loss: 0.4209
# Epoch 446/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4071 - val_loss: 0.4210
# Epoch 447/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.4074 - val_loss: 0.4210
# Epoch 448/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4060 - val_loss: 0.4211
# Epoch 449/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4074 - val_loss: 0.4209
# Epoch 450/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4051 - val_loss: 0.4213
# Epoch 451/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4050 - val_loss: 0.4212
# Epoch 452/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.4086 - val_loss: 0.4212
# Epoch 453/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4053 - val_loss: 0.4210
# Epoch 454/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4046 - val_loss: 0.4211
# Epoch 455/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4018 - val_loss: 0.4210
# Epoch 456/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4138 - val_loss: 0.4210
# Epoch 457/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4100 - val_loss: 0.4210
# Epoch 458/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4081 - val_loss: 0.4210
# Epoch 459/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4085 - val_loss: 0.4210
# Epoch 460/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4081 - val_loss: 0.4210
# Epoch 461/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4070 - val_loss: 0.4210
# Epoch 462/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4034 - val_loss: 0.4210
# Epoch 463/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.4039 - val_loss: 0.4210
# Epoch 464/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.4098 - val_loss: 0.4210
# Epoch 465/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4050 - val_loss: 0.4210
# Epoch 466/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.4065 - val_loss: 0.4211
# Epoch 467/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4070 - val_loss: 0.4211
# Epoch 468/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.4102 - val_loss: 0.4211
# Epoch 469/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4045 - val_loss: 0.4211
# Epoch 470/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4040 - val_loss: 0.4213
# Epoch 471/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4111 - val_loss: 0.4217
# Epoch 472/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4109 - val_loss: 0.4268
# Epoch 473/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4124 - val_loss: 0.4212
# Epoch 474/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4000 - val_loss: 0.4213
# Epoch 475/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.4080 - val_loss: 0.4209
# Epoch 476/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4115 - val_loss: 0.4208
# Epoch 477/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4077 - val_loss: 0.4208
# Epoch 478/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.4083 - val_loss: 0.4209
# Epoch 479/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4096 - val_loss: 0.4209
# Epoch 480/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4047 - val_loss: 0.4209
# Epoch 481/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4056 - val_loss: 0.4209
# Epoch 482/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4094 - val_loss: 0.4209
# Epoch 483/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4098 - val_loss: 0.4209
# Epoch 484/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4107 - val_loss: 0.4209
# Epoch 485/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4132 - val_loss: 0.4209
# Epoch 486/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4063 - val_loss: 0.4209
# Epoch 487/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4010 - val_loss: 0.4209
# Epoch 488/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4052 - val_loss: 0.4209
# Epoch 489/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4138 - val_loss: 0.4209
# Epoch 490/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.4078 - val_loss: 0.4209
# Epoch 491/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.4052 - val_loss: 0.4209
# Epoch 492/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4045 - val_loss: 0.4210
# Epoch 493/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4111 - val_loss: 0.4209
# Epoch 494/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4078 - val_loss: 0.4210
# Epoch 495/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.4099 - val_loss: 0.4209
# Epoch 496/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.4069 - val_loss: 0.4209
# Epoch 497/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4074 - val_loss: 0.4210
# Epoch 498/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4080 - val_loss: 0.4211
# Epoch 499/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.4086 - val_loss: 0.4211
# Epoch 500/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4098 - val_loss: 0.4210
# Epoch 501/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.4127 - val_loss: 0.4210
# Epoch 502/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.4102 - val_loss: 0.4210
# Epoch 503/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4093 - val_loss: 0.4210
# Epoch 504/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.4083 - val_loss: 0.4209
# Epoch 505/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4051 - val_loss: 0.4210
# Epoch 506/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.4070 - val_loss: 0.4211
# Epoch 507/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.4080 - val_loss: 0.4210
# Epoch 508/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.4077 - val_loss: 0.4210
# Epoch 509/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4029 - val_loss: 0.4210
# Epoch 510/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.4036 - val_loss: 0.4210
# Epoch 511/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4052 - val_loss: 0.4210
# Epoch 512/512
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.4086 - val_loss: 0.4211
# Training time: 1385.5750885009766 seconds

# %% [markdown]
# ## Encoding and Decoding Images
# Using the trained autoencoder to encode the test images.

# %%
start_time = time.time()

encoded_imgs = autoencoder.predict(x_test)

end_time = time.time()

prediction_time = end_time - start_time

print(f"Prediction time: {prediction_time} seconds")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Prediction time: 0.43320679664611816 seconds

# %% [markdown]
# ## Plotting Original and Reconstructed Images
# Plotting a comparison of the original and reconstructed images for a specified number (n) of digits.
# Displaying the original images in the top row and the reconstructed images in the bottom row.

# %%
n = 6
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(30, 40, 3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(encoded_imgs[i].reshape(30, 40, 3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# Number of images
n = 6

# Placeholder to store MSE values
mse_values = []

# Create a figure to display images
plt.figure(figsize=(20, 8))

for i in range(n):
    # Original image
    original = x_test[i].reshape(30, 40, 3)  # Assuming x_test is the dataset
    # Reconstructed image
    reconstructed = encoded_imgs[i].reshape(30, 40, 3)  # Assuming encoded_imgs are the reconstructions
    # Convert to grayscale
    original = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
    reconstructed = cv2.cvtColor(reconstructed, cv2.COLOR_BGR2GRAY)
    # Compute MSE
    mse = np.mean((original - reconstructed) ** 2)
    mse_values.append(mse)

    # Display Original Image
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(original)
    plt.title(f"\nOriginal {i+1}")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display Reconstructed Image
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(reconstructed)
    plt.title(f"\nReconstructed {i+1}")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display MSE Value
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.text(0.5, 0.5, f"MSE: {mse:.4f}", fontsize=12, ha='center', va='center')
    plt.axis('off')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# Print MSE values for reference
for i, mse in enumerate(mse_values, 1):
    print(f"Image {i}: MSE = {mse:.4f}")

# Compute the average MSE across all images
average_mse = np.mean(mse_values)
print(f"\nAverage MSE: {average_mse:.4f}")
# Out:
# Image 1: MSE = 0.0043
# Image 2: MSE = 0.0001
# Image 3: MSE = 0.0013
# Image 4: MSE = 0.0043
# Image 5: MSE = 0.0042
# Image 6: MSE = 0.0025
#
# Average MSE: 0.0028
