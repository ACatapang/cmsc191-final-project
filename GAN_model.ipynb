# %% [markdown]
# <a href="https://colab.research.google.com/github/ACatapang/cmsc191-final-project/blob/main/GAN_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library Installation
# We install the necessary libraries for GAN.

# %%
# !pip install tensorflow numpy matplotlib
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %% [markdown]
# # Library Import, Dataset, and Generator and Discriminator Definition
# We import the needed libraries, download the dataset which is in this case from the CIFAR-10 dataset, and then implement the generator and discriminator components.

# %% [markdown]
# ## Importing Libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow_datasets as tfds
import tensorflow as tf
import time
import random
import cv2
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.preprocessing.image import img_to_array

# %% [markdown]
# ## Importing dataset from Google Drive

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/Shareddrives/"CMSC 191"/"CMSC 191 GenAI Datasets"
# Out:
# 'Mango Preprocessed'

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory="/content/drive/Shareddrives/CMSC 191/CMSC 191 GenAI Datasets",
    labels='inferred',
    label_mode='categorical',
    batch_size=64,
    image_size=(30, 40))
# Out:
# Found 1620 files belonging to 1 classes.

# %%
# prompt: resize the train_ds to 28x28 images

def resize_images(image, label):
  image = tf.image.resize(image, [30, 40])
  return image, label

resized_train_ds = train_ds.map(resize_images)

# %%
# (x_train, _), (_, _) = tfds.as_numpy(resized_train_ds)
x_train = []
y_train = []
for images, labels in resized_train_ds:
    x_train.extend(images.numpy())
    y_train.extend(labels.numpy())

x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = x_train.astype('float32') / 255.0  # Normalize to [0, 1]
x_train = (x_train - 0.5) / 0.5  # Scale to [-1, 1] for GAN

# Parameters
latent_dim = 100
num_epochs = 100
batch_size = 64
sample_interval = 1000
output_dir = 'gan_output'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)
# x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))

# Generator model
def build_generator():
    model = models.Sequential()
    model.add(layers.Input(shape=(latent_dim,)))
    model.add(layers.Dense(256))
    model.add(layers.LeakyReLU(negative_slope=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(512))
    model.add(layers.LeakyReLU(negative_slope=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(1024))
    model.add(layers.LeakyReLU(negative_slope=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(30 * 40 * 3, activation='tanh'))
    model.add(layers.Reshape((30, 40, 3)))
    return model

# Discriminator model
def build_discriminator():
    model = models.Sequential()
    model.add(layers.Input(shape=(30, 40, 3)))
    model.add(layers.Flatten())
    model.add(layers.Dense(512))
    model.add(layers.LeakyReLU(negative_slope=0.2))
    model.add(layers.Dense(256))
    model.add(layers.LeakyReLU(negative_slope=0.2))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %% [markdown]
# # Building the Model Components and Training
# We build the model components discriminator and generator. We then train the model given the defined parameters.

# %%
# Start time
start_time = time.time()

batch_size = 64
num_epochs = 512

# Compile models
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Create the combined model
generator = build_generator()
z = layers.Input(shape=(latent_dim,))
img = generator(z)
discriminator.trainable = False
validity = discriminator(img)

combined = models.Model(z, validity)
combined.compile(loss='binary_crossentropy', optimizer='adam')

# Training
def sample_images(generator, epoch, rows=5, cols=5):
    noise = np.random.normal(0, 1, (rows * cols, latent_dim))
    generated_imgs = generator.predict(noise)
    generated_imgs = 0.5 * generated_imgs + 0.5  # Rescale to [0, 1]

    plt.figure(figsize=(10, 10))
    for i in range(rows * cols):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(generated_imgs[i])
        plt.axis('off')
    plt.savefig(f"{output_dir}/gan_generated_epoch_{epoch}.png")
    plt.close()

# Optionally set up TensorBoard logging
tensorboard_callback = callbacks.TensorBoard(log_dir='logs', histogram_freq=1)

# Training
for epoch in range(num_epochs):
    # Train Discriminator
    idx = np.random.randint(0, x_train.shape[0], batch_size)
    real_imgs = x_train[idx]

    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    fake_imgs = generator.predict(noise)

    d_loss_real = discriminator.train_on_batch(real_imgs, np.ones((batch_size, 1)))
    d_loss_fake = discriminator.train_on_batch(fake_imgs, np.zeros((batch_size, 1)))

    print(f"d_loss_real: {d_loss_real}, d_loss_fake: {d_loss_fake}")

    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train Generator
    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    g_loss = combined.train_on_batch(noise, np.ones((batch_size, 1)))

    # Check g_loss structure
    print(f"g_loss: {g_loss}")

    # Ensure g_loss is scalar
    g_loss_value = g_loss if isinstance(g_loss, float) else g_loss[0]  # Adjust according to actual structure

    # Print progress
    if epoch % sample_interval == 0:
        print(f"Epoch {epoch} | D loss: {d_loss[0]:.4f}, D accuracy: {100 * d_loss[1]:.2f}% | G loss: {g_loss_value:.4f}")
        sample_images(generator, epoch)

        # Log to TensorBoard
        with tf.summary.create_file_writer('logs').as_default():
            tf.summary.scalar('D loss', d_loss[0], step=epoch)
            tf.summary.scalar('D accuracy', d_loss[1], step=epoch)
            tf.summary.scalar('G loss', g_loss_value, step=epoch)


# Save models
generator.save(f"{output_dir}/generator_model.h5")
discriminator.save(f"{output_dir}/discriminator_model.h5")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# d_loss_real: [array(0.38887602, dtype=float32), array(1., dtype=float32)], d_loss_fake: [array(0.5477079, dtype=float32), array(0.7109375, dtype=float32)]
# g_loss: [array(0.5477079, dtype=float32), array(0.5477079, dtype=float32), array(0.7109375, dtype=float32)]
# Epoch 0 | D loss: 0.4683, D accuracy: 85.55% | G loss: 0.5477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7bb4ff4268c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# d_loss_real: [array(0.49468565, dtype=float32), array(0.8072917, dtype=float32)], d_loss_fake: [array(0.576751, dtype=float32), array(0.625, dtype=float32)]
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7bb4fc548d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# g_loss: [array(0.576751, dtype=float32), array(0.576751, dtype=float32), array(0.625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(0.53878516, dtype=float32), array(0.7, dtype=float32)], d_loss_fake: [array(0.61037797, dtype=float32), array(0.5833333, dtype=float32)]
# g_loss: [array(0.61037797, dtype=float32), array(0.61037797, dtype=float32), array(0.5833333, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# d_loss_real: [array(0.58121777, dtype=float32), array(0.64285713, dtype=float32)], d_loss_fake: [array(0.66308737, dtype=float32), array(0.5625, dtype=float32)]
# g_loss: [array(0.66308737, dtype=float32), array(0.66308737, dtype=float32), array(0.5625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# d_loss_real: [array(0.63277197, dtype=float32), array(0.6111111, dtype=float32)], d_loss_fake: [array(0.7402639, dtype=float32), array(0.55, dtype=float32)]
# g_loss: [array(0.7402639, dtype=float32), array(0.7402639, dtype=float32), array(0.55, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(0.7085709, dtype=float32), array(0.59090906, dtype=float32)], d_loss_fake: [array(0.83311146, dtype=float32), array(0.5416667, dtype=float32)]
# g_loss: [array(0.83311146, dtype=float32), array(0.83311146, dtype=float32), array(0.5416667, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(0.80035377, dtype=float32), array(0.5769231, dtype=float32)], d_loss_fake: [array(0.95387757, dtype=float32), array(0.53571427, dtype=float32)]
# g_loss: [array(0.95387757, dtype=float32), array(0.95387757, dtype=float32), array(0.53571427, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(0.9162752, dtype=float32), array(0.56666666, dtype=float32)], d_loss_fake: [array(1.0961996, dtype=float32), array(0.53125, dtype=float32)]
# g_loss: [array(1.0961996, dtype=float32), array(1.0961996, dtype=float32), array(0.53125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(1.0546982, dtype=float32), array(0.5588235, dtype=float32)], d_loss_fake: [array(1.2496963, dtype=float32), array(0.5277778, dtype=float32)]
# g_loss: [array(1.2496963, dtype=float32), array(1.2496963, dtype=float32), array(0.5277778, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(1.2047645, dtype=float32), array(0.5518092, dtype=float32)], d_loss_fake: [array(1.391791, dtype=float32), array(0.52421874, dtype=float32)]
# g_loss: [array(1.391791, dtype=float32), array(1.391791, dtype=float32), array(0.52421874, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(1.3439966, dtype=float32), array(0.546875, dtype=float32)], d_loss_fake: [array(1.5311595, dtype=float32), array(0.52201706, dtype=float32)]
# g_loss: [array(1.5311595, dtype=float32), array(1.5311595, dtype=float32), array(0.52201706, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(1.4819069, dtype=float32), array(0.54279894, dtype=float32)], d_loss_fake: [array(1.6750206, dtype=float32), array(0.5201823, dtype=float32)]
# g_loss: [array(1.6750206, dtype=float32), array(1.6750206, dtype=float32), array(0.5201823, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(1.6237667, dtype=float32), array(0.539375, dtype=float32)], d_loss_fake: [array(1.8189957, dtype=float32), array(0.5186298, dtype=float32)]
# g_loss: [array(1.8189957, dtype=float32), array(1.8189957, dtype=float32), array(0.5186298, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(1.7664828, dtype=float32), array(0.5364583, dtype=float32)], d_loss_fake: [array(1.9547969, dtype=float32), array(0.5172991, dtype=float32)]
# g_loss: [array(1.9547969, dtype=float32), array(1.9547969, dtype=float32), array(0.5172991, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(1.9006106, dtype=float32), array(0.53394395, dtype=float32)], d_loss_fake: [array(2.0939598, dtype=float32), array(0.5161458, dtype=float32)]
# g_loss: [array(2.0939598, dtype=float32), array(2.0939598, dtype=float32), array(0.5161458, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(2.0395522, dtype=float32), array(0.531754, dtype=float32)], d_loss_fake: [array(2.2139945, dtype=float32), array(0.5151367, dtype=float32)]
# g_loss: [array(2.2139945, dtype=float32), array(2.2139945, dtype=float32), array(0.5151367, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(2.1586125, dtype=float32), array(0.52982956, dtype=float32)], d_loss_fake: [array(2.3367538, dtype=float32), array(0.51424634, dtype=float32)]
# g_loss: [array(2.3367538, dtype=float32), array(2.3367538, dtype=float32), array(0.51424634, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(2.2810907, dtype=float32), array(0.528125, dtype=float32)], d_loss_fake: [array(2.4395125, dtype=float32), array(0.51345485, dtype=float32)]
# g_loss: [array(2.4395125, dtype=float32), array(2.4395125, dtype=float32), array(0.51345485, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# d_loss_real: [array(2.3840568, dtype=float32), array(0.5266047, dtype=float32)], d_loss_fake: [array(2.5497618, dtype=float32), array(0.5127467, dtype=float32)]
# g_loss: [array(2.5497618, dtype=float32), array(2.5497618, dtype=float32), array(0.5127467, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(2.4945834, dtype=float32), array(0.52524036, dtype=float32)], d_loss_fake: [array(2.6487973, dtype=float32), array(0.5121094, dtype=float32)]
# g_loss: [array(2.6487973, dtype=float32), array(2.6487973, dtype=float32), array(0.5121094, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(2.5940082, dtype=float32), array(0.52400917, dtype=float32)], d_loss_fake: [array(2.7425458, dtype=float32), array(0.5115327, dtype=float32)]
# g_loss: [array(2.7425458, dtype=float32), array(2.7425458, dtype=float32), array(0.5115327, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(2.6879897, dtype=float32), array(0.5228924, dtype=float32)], d_loss_fake: [array(2.834133, dtype=float32), array(0.5110085, dtype=float32)]
# g_loss: [array(2.834133, dtype=float32), array(2.834133, dtype=float32), array(0.5110085, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(2.7798884, dtype=float32), array(0.521875, dtype=float32)], d_loss_fake: [array(2.9148085, dtype=float32), array(0.5105299, dtype=float32)]
# g_loss: [array(2.9148085, dtype=float32), array(2.9148085, dtype=float32), array(0.5105299, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(2.8610222, dtype=float32), array(0.5209442, dtype=float32)], d_loss_fake: [array(2.9934924, dtype=float32), array(0.5100911, dtype=float32)]
# g_loss: [array(2.9934924, dtype=float32), array(2.9934924, dtype=float32), array(0.5100911, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(2.940584, dtype=float32), array(0.52008927, dtype=float32)], d_loss_fake: [array(3.0689259, dtype=float32), array(0.5096875, dtype=float32)]
# g_loss: [array(3.0689259, dtype=float32), array(3.0689259, dtype=float32), array(0.5096875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(3.0166357, dtype=float32), array(0.5193015, dtype=float32)], d_loss_fake: [array(3.138152, dtype=float32), array(0.5093149, dtype=float32)]
# g_loss: [array(3.138152, dtype=float32), array(3.138152, dtype=float32), array(0.5093149, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(3.0862901, dtype=float32), array(0.5185731, dtype=float32)], d_loss_fake: [array(3.2034516, dtype=float32), array(0.5089699, dtype=float32)]
# g_loss: [array(3.2034516, dtype=float32), array(3.2034516, dtype=float32), array(0.5089699, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(3.1524491, dtype=float32), array(0.5178977, dtype=float32)], d_loss_fake: [array(3.2652414, dtype=float32), array(0.5086495, dtype=float32)]
# g_loss: [array(3.2652414, dtype=float32), array(3.2652414, dtype=float32), array(0.5086495, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# d_loss_real: [array(3.2147832, dtype=float32), array(0.51726973, dtype=float32)], d_loss_fake: [array(3.3328977, dtype=float32), array(0.50835127, dtype=float32)]
# g_loss: [array(3.3328977, dtype=float32), array(3.3328977, dtype=float32), array(0.50835127, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(3.2831216, dtype=float32), array(0.5166843, dtype=float32)], d_loss_fake: [array(3.3939216, dtype=float32), array(0.5080729, dtype=float32)]
# g_loss: [array(3.3939216, dtype=float32), array(3.3939216, dtype=float32), array(0.5080729, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(3.3447282, dtype=float32), array(0.5158811, dtype=float32)], d_loss_fake: [array(3.4455588, dtype=float32), array(0.5075605, dtype=float32)]
# g_loss: [array(3.4455588, dtype=float32), array(3.4455588, dtype=float32), array(0.5075605, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(3.3970618, dtype=float32), array(0.515377, dtype=float32)], d_loss_fake: [array(3.4928339, dtype=float32), array(0.5073242, dtype=float32)]
# g_loss: [array(3.4928339, dtype=float32), array(3.4928339, dtype=float32), array(0.5073242, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# d_loss_real: [array(3.4454184, dtype=float32), array(0.51490384, dtype=float32)], d_loss_fake: [array(3.545465, dtype=float32), array(0.50710225, dtype=float32)]
# g_loss: [array(3.545465, dtype=float32), array(3.545465, dtype=float32), array(0.50710225, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(3.4982572, dtype=float32), array(0.51445895, dtype=float32)], d_loss_fake: [array(3.5989246, dtype=float32), array(0.5068934, dtype=float32)]
# g_loss: [array(3.5989246, dtype=float32), array(3.5989246, dtype=float32), array(0.5068934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# d_loss_real: [array(3.5526955, dtype=float32), array(0.5140399, dtype=float32)], d_loss_fake: [array(3.6490538, dtype=float32), array(0.5066964, dtype=float32)]
# g_loss: [array(3.6490538, dtype=float32), array(3.6490538, dtype=float32), array(0.5066964, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(3.6034143, dtype=float32), array(0.5134243, dtype=float32)], d_loss_fake: [array(3.6953099, dtype=float32), array(0.5062934, dtype=float32)]
# g_loss: [array(3.6953099, dtype=float32), array(3.6953099, dtype=float32), array(0.5062934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# d_loss_real: [array(3.6501975, dtype=float32), array(0.5130565, dtype=float32)], d_loss_fake: [array(3.7411828, dtype=float32), array(0.5061233, dtype=float32)]
# g_loss: [array(3.7411828, dtype=float32), array(3.7411828, dtype=float32), array(0.5061233, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# d_loss_real: [array(3.6968267, dtype=float32), array(0.5127083, dtype=float32)], d_loss_fake: [array(3.7807553, dtype=float32), array(0.5059622, dtype=float32)]
# g_loss: [array(3.7807553, dtype=float32), array(3.7807553, dtype=float32), array(0.5059622, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(3.7368839, dtype=float32), array(0.5123783, dtype=float32)], d_loss_fake: [array(3.8111718, dtype=float32), array(0.5058093, dtype=float32)]
# g_loss: [array(3.8111718, dtype=float32), array(3.8111718, dtype=float32), array(0.5058093, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(3.7679698, dtype=float32), array(0.5120649, dtype=float32)], d_loss_fake: [array(3.8480465, dtype=float32), array(0.50566405, dtype=float32)]
# g_loss: [array(3.8480465, dtype=float32), array(3.8480465, dtype=float32), array(0.50566405, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(3.8052433, dtype=float32), array(0.51176697, dtype=float32)], d_loss_fake: [array(3.8815947, dtype=float32), array(0.5055259, dtype=float32)]
# g_loss: [array(3.8815947, dtype=float32), array(3.8815947, dtype=float32), array(0.5055259, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(3.8396044, dtype=float32), array(0.51148343, dtype=float32)], d_loss_fake: [array(3.9166994, dtype=float32), array(0.50539434, dtype=float32)]
# g_loss: [array(3.9166994, dtype=float32), array(3.9166994, dtype=float32), array(0.50539434, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(3.8753462, dtype=float32), array(0.5110294, dtype=float32)], d_loss_fake: [array(3.9562109, dtype=float32), array(0.5050872, dtype=float32)]
# g_loss: [array(3.9562109, dtype=float32), array(3.9562109, dtype=float32), array(0.5050872, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(3.915344, dtype=float32), array(0.51077586, dtype=float32)], d_loss_fake: [array(3.9876928, dtype=float32), array(0.50497156, dtype=float32)]
# g_loss: [array(3.9876928, dtype=float32), array(3.9876928, dtype=float32), array(0.50497156, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# d_loss_real: [array(3.9472218, dtype=float32), array(0.5105337, dtype=float32)], d_loss_fake: [array(4.0196466, dtype=float32), array(0.5048611, dtype=float32)]
# g_loss: [array(4.0196466, dtype=float32), array(4.0196466, dtype=float32), array(0.5048611, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(3.9796698, dtype=float32), array(0.5103022, dtype=float32)], d_loss_fake: [array(4.0473237, dtype=float32), array(0.50475544, dtype=float32)]
# g_loss: [array(4.0473237, dtype=float32), array(4.0473237, dtype=float32), array(0.50475544, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(4.0080338, dtype=float32), array(0.51008064, dtype=float32)], d_loss_fake: [array(4.0731187, dtype=float32), array(0.5046542, dtype=float32)]
# g_loss: [array(4.0731187, dtype=float32), array(4.0731187, dtype=float32), array(0.5046542, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.0343575, dtype=float32), array(0.50986844, dtype=float32)], d_loss_fake: [array(4.102384, dtype=float32), array(0.5045573, dtype=float32)]
# g_loss: [array(4.102384, dtype=float32), array(4.102384, dtype=float32), array(0.5045573, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.064166, dtype=float32), array(0.50966495, dtype=float32)], d_loss_fake: [array(4.1298842, dtype=float32), array(0.50446427, dtype=float32)]
# g_loss: [array(4.1298842, dtype=float32), array(4.1298842, dtype=float32), array(0.50446427, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.091951, dtype=float32), array(0.5094697, dtype=float32)], d_loss_fake: [array(4.154481, dtype=float32), array(0.504375, dtype=float32)]
# g_loss: [array(4.154481, dtype=float32), array(4.154481, dtype=float32), array(0.504375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(4.117317, dtype=float32), array(0.5092822, dtype=float32)], d_loss_fake: [array(4.1802735, dtype=float32), array(0.5042892, dtype=float32)]
# g_loss: [array(4.1802735, dtype=float32), array(4.1802735, dtype=float32), array(0.5042892, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.1435375, dtype=float32), array(0.5091019, dtype=float32)], d_loss_fake: [array(4.2042665, dtype=float32), array(0.5042067, dtype=float32)]
# g_loss: [array(4.2042665, dtype=float32), array(4.2042665, dtype=float32), array(0.5042067, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(4.1679883, dtype=float32), array(0.5089286, dtype=float32)], d_loss_fake: [array(4.231299, dtype=float32), array(0.5041274, dtype=float32)]
# g_loss: [array(4.231299, dtype=float32), array(4.231299, dtype=float32), array(0.5041274, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(4.195563, dtype=float32), array(0.5087617, dtype=float32)], d_loss_fake: [array(4.249415, dtype=float32), array(0.5040509, dtype=float32)]
# g_loss: [array(4.249415, dtype=float32), array(4.249415, dtype=float32), array(0.5040509, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# d_loss_real: [array(4.214033, dtype=float32), array(0.5086009, dtype=float32)], d_loss_fake: [array(4.266752, dtype=float32), array(0.5039773, dtype=float32)]
# g_loss: [array(4.266752, dtype=float32), array(4.266752, dtype=float32), array(0.5039773, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# d_loss_real: [array(4.231828, dtype=float32), array(0.5084459, dtype=float32)], d_loss_fake: [array(4.284861, dtype=float32), array(0.50390625, dtype=float32)]
# g_loss: [array(4.284861, dtype=float32), array(4.284861, dtype=float32), array(0.50390625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(4.250428, dtype=float32), array(0.5082965, dtype=float32)], d_loss_fake: [array(4.301302, dtype=float32), array(0.5038377, dtype=float32)]
# g_loss: [array(4.301302, dtype=float32), array(4.301302, dtype=float32), array(0.5038377, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.2672086, dtype=float32), array(0.5081522, dtype=float32)], d_loss_fake: [array(4.32244, dtype=float32), array(0.50377154, dtype=float32)]
# g_loss: [array(4.32244, dtype=float32), array(4.32244, dtype=float32), array(0.50377154, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.2888346, dtype=float32), array(0.50801283, dtype=float32)], d_loss_fake: [array(4.3420734, dtype=float32), array(0.50370765, dtype=float32)]
# g_loss: [array(4.3420734, dtype=float32), array(4.3420734, dtype=float32), array(0.50370765, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.30875, dtype=float32), array(0.5078781, dtype=float32)], d_loss_fake: [array(4.3602347, dtype=float32), array(0.50364584, dtype=float32)]
# g_loss: [array(4.3602347, dtype=float32), array(4.3602347, dtype=float32), array(0.50364584, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.327488, dtype=float32), array(0.5076188, dtype=float32)], d_loss_fake: [array(4.3772316, dtype=float32), array(0.50345796, dtype=float32)]
# g_loss: [array(4.3772316, dtype=float32), array(4.3772316, dtype=float32), array(0.50345796, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.344914, dtype=float32), array(0.5074949, dtype=float32)], d_loss_fake: [array(4.3939295, dtype=float32), array(0.50340223, dtype=float32)]
# g_loss: [array(4.3939295, dtype=float32), array(4.3939295, dtype=float32), array(0.50340223, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(4.361918, dtype=float32), array(0.507375, dtype=float32)], d_loss_fake: [array(4.412813, dtype=float32), array(0.50334823, dtype=float32)]
# g_loss: [array(4.412813, dtype=float32), array(4.412813, dtype=float32), array(0.50334823, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.3811107, dtype=float32), array(0.50725883, dtype=float32)], d_loss_fake: [array(4.424978, dtype=float32), array(0.5032959, dtype=float32)]
# g_loss: [array(4.424978, dtype=float32), array(4.424978, dtype=float32), array(0.5032959, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(4.3937263, dtype=float32), array(0.5071463, dtype=float32)], d_loss_fake: [array(4.438495, dtype=float32), array(0.5032452, dtype=float32)]
# g_loss: [array(4.438495, dtype=float32), array(4.438495, dtype=float32), array(0.5032452, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.4076166, dtype=float32), array(0.5070372, dtype=float32)], d_loss_fake: [array(4.4496655, dtype=float32), array(0.503196, dtype=float32)]
# g_loss: [array(4.4496655, dtype=float32), array(4.4496655, dtype=float32), array(0.503196, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(4.4191585, dtype=float32), array(0.50693136, dtype=float32)], d_loss_fake: [array(4.4665246, dtype=float32), array(0.5031483, dtype=float32)]
# g_loss: [array(4.4665246, dtype=float32), array(4.4665246, dtype=float32), array(0.5031483, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(4.436322, dtype=float32), array(0.5068287, dtype=float32)], d_loss_fake: [array(4.4831786, dtype=float32), array(0.503102, dtype=float32)]
# g_loss: [array(4.4831786, dtype=float32), array(4.4831786, dtype=float32), array(0.503102, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.4533157, dtype=float32), array(0.506729, dtype=float32)], d_loss_fake: [array(4.4992394, dtype=float32), array(0.50305706, dtype=float32)]
# g_loss: [array(4.4992394, dtype=float32), array(4.4992394, dtype=float32), array(0.50305706, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# d_loss_real: [array(4.469732, dtype=float32), array(0.5066322, dtype=float32)], d_loss_fake: [array(4.514448, dtype=float32), array(0.5030134, dtype=float32)]
# g_loss: [array(4.514448, dtype=float32), array(4.514448, dtype=float32), array(0.5030134, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(4.4853168, dtype=float32), array(0.5065381, dtype=float32)], d_loss_fake: [array(4.529844, dtype=float32), array(0.50297093, dtype=float32)]
# g_loss: [array(4.529844, dtype=float32), array(4.529844, dtype=float32), array(0.50297093, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.5008745, dtype=float32), array(0.50644666, dtype=float32)], d_loss_fake: [array(4.5425687, dtype=float32), array(0.5029297, dtype=float32)]
# g_loss: [array(4.5425687, dtype=float32), array(4.5425687, dtype=float32), array(0.5029297, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# d_loss_real: [array(4.5140257, dtype=float32), array(0.5063577, dtype=float32)], d_loss_fake: [array(4.557541, dtype=float32), array(0.5028896, dtype=float32)]
# g_loss: [array(4.557541, dtype=float32), array(4.557541, dtype=float32), array(0.5028896, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.5292525, dtype=float32), array(0.50627124, dtype=float32)], d_loss_fake: [array(4.5695376, dtype=float32), array(0.50285053, dtype=float32)]
# g_loss: [array(4.5695376, dtype=float32), array(4.5695376, dtype=float32), array(0.50285053, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.541578, dtype=float32), array(0.5061871, dtype=float32)], d_loss_fake: [array(4.584992, dtype=float32), array(0.5028125, dtype=float32)]
# g_loss: [array(4.584992, dtype=float32), array(4.584992, dtype=float32), array(0.5028125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# d_loss_real: [array(4.5571613, dtype=float32), array(0.5061051, dtype=float32)], d_loss_fake: [array(4.5974255, dtype=float32), array(0.5027755, dtype=float32)]
# g_loss: [array(4.5974255, dtype=float32), array(4.5974255, dtype=float32), array(0.5027755, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.5700426, dtype=float32), array(0.5060253, dtype=float32)], d_loss_fake: [array(4.609564, dtype=float32), array(0.5027394, dtype=float32)]
# g_loss: [array(4.609564, dtype=float32), array(4.609564, dtype=float32), array(0.5027394, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.5823693, dtype=float32), array(0.5059476, dtype=float32)], d_loss_fake: [array(4.617262, dtype=float32), array(0.5027043, dtype=float32)]
# g_loss: [array(4.617262, dtype=float32), array(4.617262, dtype=float32), array(0.5027043, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.5903687, dtype=float32), array(0.50587183, dtype=float32)], d_loss_fake: [array(4.6285176, dtype=float32), array(0.5026701, dtype=float32)]
# g_loss: [array(4.6285176, dtype=float32), array(4.6285176, dtype=float32), array(0.5026701, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.601947, dtype=float32), array(0.505798, dtype=float32)], d_loss_fake: [array(4.640787, dtype=float32), array(0.50263673, dtype=float32)]
# g_loss: [array(4.640787, dtype=float32), array(4.640787, dtype=float32), array(0.50263673, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.614316, dtype=float32), array(0.5057259, dtype=float32)], d_loss_fake: [array(4.653402, dtype=float32), array(0.5026042, dtype=float32)]
# g_loss: [array(4.653402, dtype=float32), array(4.653402, dtype=float32), array(0.5026042, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.627256, dtype=float32), array(0.50565565, dtype=float32)], d_loss_fake: [array(4.6650734, dtype=float32), array(0.5025724, dtype=float32)]
# g_loss: [array(4.6650734, dtype=float32), array(4.6650734, dtype=float32), array(0.5025724, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.6391654, dtype=float32), array(0.5055871, dtype=float32)], d_loss_fake: [array(4.6743107, dtype=float32), array(0.5025414, dtype=float32)]
# g_loss: [array(4.6743107, dtype=float32), array(4.6743107, dtype=float32), array(0.5025414, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.648639, dtype=float32), array(0.5055202, dtype=float32)], d_loss_fake: [array(4.686548, dtype=float32), array(0.50251114, dtype=float32)]
# g_loss: [array(4.686548, dtype=float32), array(4.686548, dtype=float32), array(0.50251114, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.6611567, dtype=float32), array(0.5054549, dtype=float32)], d_loss_fake: [array(4.6950455, dtype=float32), array(0.50248164, dtype=float32)]
# g_loss: [array(4.6950455, dtype=float32), array(4.6950455, dtype=float32), array(0.50248164, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(4.6699266, dtype=float32), array(0.50539106, dtype=float32)], d_loss_fake: [array(4.7023134, dtype=float32), array(0.5024528, dtype=float32)]
# g_loss: [array(4.7023134, dtype=float32), array(4.7023134, dtype=float32), array(0.5024528, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.6774354, dtype=float32), array(0.5053288, dtype=float32)], d_loss_fake: [array(4.711343, dtype=float32), array(0.5024246, dtype=float32)]
# g_loss: [array(4.711343, dtype=float32), array(4.711343, dtype=float32), array(0.5024246, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# d_loss_real: [array(4.68671, dtype=float32), array(0.50526786, dtype=float32)], d_loss_fake: [array(4.719047, dtype=float32), array(0.502397, dtype=float32)]
# g_loss: [array(4.719047, dtype=float32), array(4.719047, dtype=float32), array(0.502397, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(4.694687, dtype=float32), array(0.5052083, dtype=float32)], d_loss_fake: [array(4.73069, dtype=float32), array(0.50237006, dtype=float32)]
# g_loss: [array(4.73069, dtype=float32), array(4.73069, dtype=float32), array(0.50237006, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# d_loss_real: [array(4.7064, dtype=float32), array(0.50515014, dtype=float32)], d_loss_fake: [array(4.7400036, dtype=float32), array(0.5023438, dtype=float32)]
# g_loss: [array(4.7400036, dtype=float32), array(4.7400036, dtype=float32), array(0.5023438, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(4.715952, dtype=float32), array(0.5050932, dtype=float32)], d_loss_fake: [array(4.74908, dtype=float32), array(0.50231797, dtype=float32)]
# g_loss: [array(4.74908, dtype=float32), array(4.74908, dtype=float32), array(0.50231797, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# d_loss_real: [array(4.7252946, dtype=float32), array(0.50503755, dtype=float32)], d_loss_fake: [array(4.757318, dtype=float32), array(0.5022928, dtype=float32)]
# g_loss: [array(4.757318, dtype=float32), array(4.757318, dtype=float32), array(0.5022928, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.7337155, dtype=float32), array(0.5049831, dtype=float32)], d_loss_fake: [array(4.767122, dtype=float32), array(0.50226814, dtype=float32)]
# g_loss: [array(4.767122, dtype=float32), array(4.767122, dtype=float32), array(0.50226814, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.7436466, dtype=float32), array(0.5048463, dtype=float32)], d_loss_fake: [array(4.7740264, dtype=float32), array(0.5021609, dtype=float32)]
# g_loss: [array(4.7740264, dtype=float32), array(4.7740264, dtype=float32), array(0.5021609, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.75082, dtype=float32), array(0.50479496, dtype=float32)], d_loss_fake: [array(4.783819, dtype=float32), array(0.50213814, dtype=float32)]
# g_loss: [array(4.783819, dtype=float32), array(4.783819, dtype=float32), array(0.50213814, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.7608094, dtype=float32), array(0.50474477, dtype=float32)], d_loss_fake: [array(4.7925396, dtype=float32), array(0.5021159, dtype=float32)]
# g_loss: [array(4.7925396, dtype=float32), array(4.7925396, dtype=float32), array(0.5021159, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.769738, dtype=float32), array(0.5046956, dtype=float32)], d_loss_fake: [array(4.800567, dtype=float32), array(0.5020941, dtype=float32)]
# g_loss: [array(4.800567, dtype=float32), array(4.800567, dtype=float32), array(0.5020941, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(4.777974, dtype=float32), array(0.50464743, dtype=float32)], d_loss_fake: [array(4.809462, dtype=float32), array(0.5020727, dtype=float32)]
# g_loss: [array(4.809462, dtype=float32), array(4.809462, dtype=float32), array(0.5020727, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.78706, dtype=float32), array(0.5046002, dtype=float32)], d_loss_fake: [array(4.815824, dtype=float32), array(0.5020518, dtype=float32)]
# g_loss: [array(4.815824, dtype=float32), array(4.815824, dtype=float32), array(0.5020518, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.793607, dtype=float32), array(0.50455403, dtype=float32)], d_loss_fake: [array(4.823591, dtype=float32), array(0.50203127, dtype=float32)]
# g_loss: [array(4.823591, dtype=float32), array(4.823591, dtype=float32), array(0.50203127, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.80154, dtype=float32), array(0.50450873, dtype=float32)], d_loss_fake: [array(4.8295455, dtype=float32), array(0.5020111, dtype=float32)]
# g_loss: [array(4.8295455, dtype=float32), array(4.8295455, dtype=float32), array(0.5020111, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.807727, dtype=float32), array(0.50446427, dtype=float32)], d_loss_fake: [array(4.836911, dtype=float32), array(0.50199145, dtype=float32)]
# g_loss: [array(4.836911, dtype=float32), array(4.836911, dtype=float32), array(0.50199145, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.815271, dtype=float32), array(0.50442076, dtype=float32)], d_loss_fake: [array(4.845234, dtype=float32), array(0.5019721, dtype=float32)]
# g_loss: [array(4.845234, dtype=float32), array(4.845234, dtype=float32), array(0.5019721, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.8237467, dtype=float32), array(0.504378, dtype=float32)], d_loss_fake: [array(4.852582, dtype=float32), array(0.5019531, dtype=float32)]
# g_loss: [array(4.852582, dtype=float32), array(4.852582, dtype=float32), array(0.5019531, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# d_loss_real: [array(4.8312263, dtype=float32), array(0.5043361, dtype=float32)], d_loss_fake: [array(4.8595424, dtype=float32), array(0.5019345, dtype=float32)]
# g_loss: [array(4.8595424, dtype=float32), array(4.8595424, dtype=float32), array(0.5019345, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(4.83836, dtype=float32), array(0.50429505, dtype=float32)], d_loss_fake: [array(4.8651743, dtype=float32), array(0.5019163, dtype=float32)]
# g_loss: [array(4.8651743, dtype=float32), array(4.8651743, dtype=float32), array(0.5019163, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# d_loss_real: [array(4.8441586, dtype=float32), array(0.5042547, dtype=float32)], d_loss_fake: [array(4.8712573, dtype=float32), array(0.50189835, dtype=float32)]
# g_loss: [array(4.8712573, dtype=float32), array(4.8712573, dtype=float32), array(0.50189835, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# d_loss_real: [array(4.850409, dtype=float32), array(0.5042151, dtype=float32)], d_loss_fake: [array(4.8781533, dtype=float32), array(0.50188076, dtype=float32)]
# g_loss: [array(4.8781533, dtype=float32), array(4.8781533, dtype=float32), array(0.50188076, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.8574667, dtype=float32), array(0.50417626, dtype=float32)], d_loss_fake: [array(4.8846703, dtype=float32), array(0.50186354, dtype=float32)]
# g_loss: [array(4.8846703, dtype=float32), array(4.8846703, dtype=float32), array(0.50186354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.8642373, dtype=float32), array(0.50406677, dtype=float32)], d_loss_fake: [array(4.8913984, dtype=float32), array(0.50177556, dtype=float32)]
# g_loss: [array(4.8913984, dtype=float32), array(4.8913984, dtype=float32), array(0.50177556, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# d_loss_real: [array(4.871035, dtype=float32), array(0.50403, dtype=float32)], d_loss_fake: [array(4.897936, dtype=float32), array(0.5017596, dtype=float32)]
# g_loss: [array(4.897936, dtype=float32), array(4.897936, dtype=float32), array(0.5017596, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.8777227, dtype=float32), array(0.5039938, dtype=float32)], d_loss_fake: [array(4.9044604, dtype=float32), array(0.50174385, dtype=float32)]
# g_loss: [array(4.9044604, dtype=float32), array(4.9044604, dtype=float32), array(0.50174385, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.8843966, dtype=float32), array(0.50395834, dtype=float32)], d_loss_fake: [array(4.9100733, dtype=float32), array(0.5017284, dtype=float32)]
# g_loss: [array(4.9100733, dtype=float32), array(4.9100733, dtype=float32), array(0.5017284, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.8901553, dtype=float32), array(0.5039235, dtype=float32)], d_loss_fake: [array(4.916269, dtype=float32), array(0.5017133, dtype=float32)]
# g_loss: [array(4.916269, dtype=float32), array(4.916269, dtype=float32), array(0.5017133, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.8964734, dtype=float32), array(0.5038892, dtype=float32)], d_loss_fake: [array(4.9225526, dtype=float32), array(0.5016984, dtype=float32)]
# g_loss: [array(4.9225526, dtype=float32), array(4.9225526, dtype=float32), array(0.5016984, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.9029655, dtype=float32), array(0.5038555, dtype=float32)], d_loss_fake: [array(4.9285626, dtype=float32), array(0.5016837, dtype=float32)]
# g_loss: [array(4.9285626, dtype=float32), array(4.9285626, dtype=float32), array(0.5016837, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.9090576, dtype=float32), array(0.50382245, dtype=float32)], d_loss_fake: [array(4.935493, dtype=float32), array(0.50166935, dtype=float32)]
# g_loss: [array(4.935493, dtype=float32), array(4.935493, dtype=float32), array(0.50166935, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.916237, dtype=float32), array(0.5037899, dtype=float32)], d_loss_fake: [array(4.940762, dtype=float32), array(0.50165516, dtype=float32)]
# g_loss: [array(4.940762, dtype=float32), array(4.940762, dtype=float32), array(0.50165516, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.921664, dtype=float32), array(0.5037579, dtype=float32)], d_loss_fake: [array(4.946466, dtype=float32), array(0.5016413, dtype=float32)]
# g_loss: [array(4.946466, dtype=float32), array(4.946466, dtype=float32), array(0.5016413, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.9274693, dtype=float32), array(0.5037265, dtype=float32)], d_loss_fake: [array(4.9519267, dtype=float32), array(0.5016276, dtype=float32)]
# g_loss: [array(4.9519267, dtype=float32), array(4.9519267, dtype=float32), array(0.5016276, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.932994, dtype=float32), array(0.50369555, dtype=float32)], d_loss_fake: [array(4.9571085, dtype=float32), array(0.50161415, dtype=float32)]
# g_loss: [array(4.9571085, dtype=float32), array(4.9571085, dtype=float32), array(0.50161415, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(4.9382987, dtype=float32), array(0.50366515, dtype=float32)], d_loss_fake: [array(4.9635386, dtype=float32), array(0.5016009, dtype=float32)]
# g_loss: [array(4.9635386, dtype=float32), array(4.9635386, dtype=float32), array(0.5016009, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(4.944889, dtype=float32), array(0.5036352, dtype=float32)], d_loss_fake: [array(4.969772, dtype=float32), array(0.5015879, dtype=float32)]
# g_loss: [array(4.969772, dtype=float32), array(4.969772, dtype=float32), array(0.5015879, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# d_loss_real: [array(4.951219, dtype=float32), array(0.5036058, dtype=float32)], d_loss_fake: [array(4.9757676, dtype=float32), array(0.5015751, dtype=float32)]
# g_loss: [array(4.9757676, dtype=float32), array(4.9757676, dtype=float32), array(0.5015751, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(4.957288, dtype=float32), array(0.5035768, dtype=float32)], d_loss_fake: [array(4.9794445, dtype=float32), array(0.5015625, dtype=float32)]
# g_loss: [array(4.9794445, dtype=float32), array(4.9794445, dtype=float32), array(0.5015625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(4.9611664, dtype=float32), array(0.5035483, dtype=float32)], d_loss_fake: [array(4.9844737, dtype=float32), array(0.5015501, dtype=float32)]
# g_loss: [array(4.9844737, dtype=float32), array(4.9844737, dtype=float32), array(0.5015501, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(4.9663587, dtype=float32), array(0.50352025, dtype=float32)], d_loss_fake: [array(4.9886904, dtype=float32), array(0.5015379, dtype=float32)]
# g_loss: [array(4.9886904, dtype=float32), array(4.9886904, dtype=float32), array(0.5015379, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.97065, dtype=float32), array(0.50349265, dtype=float32)], d_loss_fake: [array(4.993756, dtype=float32), array(0.5015259, dtype=float32)]
# g_loss: [array(4.993756, dtype=float32), array(4.993756, dtype=float32), array(0.5015259, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(4.975897, dtype=float32), array(0.5034655, dtype=float32)], d_loss_fake: [array(4.999498, dtype=float32), array(0.5015141, dtype=float32)]
# g_loss: [array(4.999498, dtype=float32), array(4.999498, dtype=float32), array(0.5015141, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(4.9816866, dtype=float32), array(0.5034387, dtype=float32)], d_loss_fake: [array(5.004763, dtype=float32), array(0.5015024, dtype=float32)]
# g_loss: [array(5.004763, dtype=float32), array(5.004763, dtype=float32), array(0.5015024, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(4.9871216, dtype=float32), array(0.50341237, dtype=float32)], d_loss_fake: [array(5.010433, dtype=float32), array(0.50149095, dtype=float32)]
# g_loss: [array(5.010433, dtype=float32), array(5.010433, dtype=float32), array(0.50149095, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(4.9928217, dtype=float32), array(0.5033864, dtype=float32)], d_loss_fake: [array(5.0144706, dtype=float32), array(0.5014796, dtype=float32)]
# g_loss: [array(5.0144706, dtype=float32), array(5.0144706, dtype=float32), array(0.5014796, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(4.997038, dtype=float32), array(0.50336087, dtype=float32)], d_loss_fake: [array(5.0188656, dtype=float32), array(0.50146854, dtype=float32)]
# g_loss: [array(5.0188656, dtype=float32), array(5.0188656, dtype=float32), array(0.50146854, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.0015607, dtype=float32), array(0.50333565, dtype=float32)], d_loss_fake: [array(5.0237126, dtype=float32), array(0.5014576, dtype=float32)]
# g_loss: [array(5.0237126, dtype=float32), array(5.0237126, dtype=float32), array(0.5014576, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.0065036, dtype=float32), array(0.50331086, dtype=float32)], d_loss_fake: [array(5.0281396, dtype=float32), array(0.5014468, dtype=float32)]
# g_loss: [array(5.0281396, dtype=float32), array(5.0281396, dtype=float32), array(0.5014468, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.011078, dtype=float32), array(0.5032864, dtype=float32)], d_loss_fake: [array(5.0325446, dtype=float32), array(0.5014361, dtype=float32)]
# g_loss: [array(5.0325446, dtype=float32), array(5.0325446, dtype=float32), array(0.5014361, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.0155644, dtype=float32), array(0.50326234, dtype=float32)], d_loss_fake: [array(5.0366383, dtype=float32), array(0.5014256, dtype=float32)]
# g_loss: [array(5.0366383, dtype=float32), array(5.0366383, dtype=float32), array(0.5014256, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.01972, dtype=float32), array(0.5032386, dtype=float32)], d_loss_fake: [array(5.040389, dtype=float32), array(0.5014153, dtype=float32)]
# g_loss: [array(5.040389, dtype=float32), array(5.040389, dtype=float32), array(0.5014153, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.0236177, dtype=float32), array(0.50321525, dtype=float32)], d_loss_fake: [array(5.0454283, dtype=float32), array(0.5014051, dtype=float32)]
# g_loss: [array(5.0454283, dtype=float32), array(5.0454283, dtype=float32), array(0.5014051, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(5.0287724, dtype=float32), array(0.5031362, dtype=float32)], d_loss_fake: [array(5.049926, dtype=float32), array(0.50133926, dtype=float32)]
# g_loss: [array(5.049926, dtype=float32), array(5.049926, dtype=float32), array(0.50133926, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# d_loss_real: [array(5.0333095, dtype=float32), array(0.50311387, dtype=float32)], d_loss_fake: [array(5.0538335, dtype=float32), array(0.5013298, dtype=float32)]
# g_loss: [array(5.0538335, dtype=float32), array(5.0538335, dtype=float32), array(0.5013298, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# d_loss_real: [array(5.0373917, dtype=float32), array(0.5030919, dtype=float32)], d_loss_fake: [array(5.0599213, dtype=float32), array(0.5013204, dtype=float32)]
# g_loss: [array(5.0599213, dtype=float32), array(5.0599213, dtype=float32), array(0.5013204, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(5.0435524, dtype=float32), array(0.5030702, dtype=float32)], d_loss_fake: [array(5.0644503, dtype=float32), array(0.5013112, dtype=float32)]
# g_loss: [array(5.0644503, dtype=float32), array(5.0644503, dtype=float32), array(0.5013112, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.0481734, dtype=float32), array(0.5030488, dtype=float32)], d_loss_fake: [array(5.0693483, dtype=float32), array(0.50130206, dtype=float32)]
# g_loss: [array(5.0693483, dtype=float32), array(5.0693483, dtype=float32), array(0.50130206, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.0531445, dtype=float32), array(0.5030277, dtype=float32)], d_loss_fake: [array(5.073856, dtype=float32), array(0.5012931, dtype=float32)]
# g_loss: [array(5.073856, dtype=float32), array(5.073856, dtype=float32), array(0.5012931, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.057786, dtype=float32), array(0.5030069, dtype=float32)], d_loss_fake: [array(5.0782375, dtype=float32), array(0.50128424, dtype=float32)]
# g_loss: [array(5.0782375, dtype=float32), array(5.0782375, dtype=float32), array(0.50128424, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.062261, dtype=float32), array(0.5029864, dtype=float32)], d_loss_fake: [array(5.0818872, dtype=float32), array(0.50127554, dtype=float32)]
# g_loss: [array(5.0818872, dtype=float32), array(5.0818872, dtype=float32), array(0.50127554, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.065975, dtype=float32), array(0.5029661, dtype=float32)], d_loss_fake: [array(5.0862646, dtype=float32), array(0.5012669, dtype=float32)]
# g_loss: [array(5.0862646, dtype=float32), array(5.0862646, dtype=float32), array(0.5012669, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.070455, dtype=float32), array(0.50294614, dtype=float32)], d_loss_fake: [array(5.0892134, dtype=float32), array(0.5012584, dtype=float32)]
# g_loss: [array(5.0892134, dtype=float32), array(5.0892134, dtype=float32), array(0.5012584, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.07354, dtype=float32), array(0.5029264, dtype=float32)], d_loss_fake: [array(5.0927305, dtype=float32), array(0.50125, dtype=float32)]
# g_loss: [array(5.0927305, dtype=float32), array(5.0927305, dtype=float32), array(0.50125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.077111, dtype=float32), array(0.502907, dtype=float32)], d_loss_fake: [array(5.096058, dtype=float32), array(0.50124174, dtype=float32)]
# g_loss: [array(5.096058, dtype=float32), array(5.096058, dtype=float32), array(0.50124174, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# ...
# g_loss: [array(5.527576, dtype=float32), array(5.527576, dtype=float32), array(0.5002776, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.521073, dtype=float32), array(0.50091094, dtype=float32)], d_loss_fake: [array(5.529055, dtype=float32), array(0.5002769, dtype=float32)]
# g_loss: [array(5.529055, dtype=float32), array(5.529055, dtype=float32), array(0.5002769, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.522551, dtype=float32), array(0.5009087, dtype=float32)], d_loss_fake: [array(5.5300217, dtype=float32), array(0.5002762, dtype=float32)]
# g_loss: [array(5.5300217, dtype=float32), array(5.5300217, dtype=float32), array(0.5002762, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(5.523537, dtype=float32), array(0.50090635, dtype=float32)], d_loss_fake: [array(5.5306506, dtype=float32), array(0.5002755, dtype=float32)]
# g_loss: [array(5.5306506, dtype=float32), array(5.5306506, dtype=float32), array(0.5002755, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.524203, dtype=float32), array(0.5008844, dtype=float32)], d_loss_fake: [array(5.531454, dtype=float32), array(0.50025517, dtype=float32)]
# g_loss: [array(5.531454, dtype=float32), array(5.531454, dtype=float32), array(0.50025517, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(5.525002, dtype=float32), array(0.5008822, dtype=float32)], d_loss_fake: [array(5.5324116, dtype=float32), array(0.5002546, dtype=float32)]
# g_loss: [array(5.5324116, dtype=float32), array(5.5324116, dtype=float32), array(0.5002546, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.525973, dtype=float32), array(0.50088, dtype=float32)], d_loss_fake: [array(5.533144, dtype=float32), array(0.5002539, dtype=float32)]
# g_loss: [array(5.533144, dtype=float32), array(5.533144, dtype=float32), array(0.5002539, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(5.5267305, dtype=float32), array(0.5008778, dtype=float32)], d_loss_fake: [array(5.533914, dtype=float32), array(0.50025326, dtype=float32)]
# g_loss: [array(5.533914, dtype=float32), array(5.533914, dtype=float32), array(0.50025326, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5275164, dtype=float32), array(0.50087565, dtype=float32)], d_loss_fake: [array(5.534551, dtype=float32), array(0.50025266, dtype=float32)]
# g_loss: [array(5.534551, dtype=float32), array(5.534551, dtype=float32), array(0.50025266, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5281973, dtype=float32), array(0.50087345, dtype=float32)], d_loss_fake: [array(5.5357256, dtype=float32), array(0.500252, dtype=float32)]
# g_loss: [array(5.5357256, dtype=float32), array(5.5357256, dtype=float32), array(0.500252, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# d_loss_real: [array(5.529346, dtype=float32), array(0.5008713, dtype=float32)], d_loss_fake: [array(5.536791, dtype=float32), array(0.5002514, dtype=float32)]
# g_loss: [array(5.536791, dtype=float32), array(5.536791, dtype=float32), array(0.5002514, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.5304356, dtype=float32), array(0.50086915, dtype=float32)], d_loss_fake: [array(5.5375357, dtype=float32), array(0.50025076, dtype=float32)]
# g_loss: [array(5.5375357, dtype=float32), array(5.5375357, dtype=float32), array(0.50025076, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# d_loss_real: [array(5.5311995, dtype=float32), array(0.500867, dtype=float32)], d_loss_fake: [array(5.538259, dtype=float32), array(0.50025016, dtype=float32)]
# g_loss: [array(5.538259, dtype=float32), array(5.538259, dtype=float32), array(0.50025016, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(5.5319343, dtype=float32), array(0.50086486, dtype=float32)], d_loss_fake: [array(5.5393786, dtype=float32), array(0.50024956, dtype=float32)]
# g_loss: [array(5.5393786, dtype=float32), array(5.5393786, dtype=float32), array(0.50024956, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(5.533046, dtype=float32), array(0.5008627, dtype=float32)], d_loss_fake: [array(5.539729, dtype=float32), array(0.5002489, dtype=float32)]
# g_loss: [array(5.539729, dtype=float32), array(5.539729, dtype=float32), array(0.5002489, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.53343, dtype=float32), array(0.50086063, dtype=float32)], d_loss_fake: [array(5.5404506, dtype=float32), array(0.5002483, dtype=float32)]
# g_loss: [array(5.5404506, dtype=float32), array(5.5404506, dtype=float32), array(0.5002483, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.53417, dtype=float32), array(0.50085855, dtype=float32)], d_loss_fake: [array(5.5415587, dtype=float32), array(0.5002477, dtype=float32)]
# g_loss: [array(5.5415587, dtype=float32), array(5.5415587, dtype=float32), array(0.5002477, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# d_loss_real: [array(5.5352836, dtype=float32), array(0.5008564, dtype=float32)], d_loss_fake: [array(5.5425463, dtype=float32), array(0.5002471, dtype=float32)]
# g_loss: [array(5.5425463, dtype=float32), array(5.5425463, dtype=float32), array(0.5002471, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.5363097, dtype=float32), array(0.5008544, dtype=float32)], d_loss_fake: [array(5.54352, dtype=float32), array(0.5002465, dtype=float32)]
# g_loss: [array(5.54352, dtype=float32), array(5.54352, dtype=float32), array(0.5002465, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.537269, dtype=float32), array(0.5008523, dtype=float32)], d_loss_fake: [array(5.544482, dtype=float32), array(0.5002459, dtype=float32)]
# g_loss: [array(5.544482, dtype=float32), array(5.544482, dtype=float32), array(0.5002459, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5382485, dtype=float32), array(0.5008502, dtype=float32)], d_loss_fake: [array(5.545736, dtype=float32), array(0.50024533, dtype=float32)]
# g_loss: [array(5.545736, dtype=float32), array(5.545736, dtype=float32), array(0.50024533, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5395474, dtype=float32), array(0.5008482, dtype=float32)], d_loss_fake: [array(5.546259, dtype=float32), array(0.50024474, dtype=float32)]
# g_loss: [array(5.546259, dtype=float32), array(5.546259, dtype=float32), array(0.50024474, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.540059, dtype=float32), array(0.50084615, dtype=float32)], d_loss_fake: [array(5.5472684, dtype=float32), array(0.50024414, dtype=float32)]
# g_loss: [array(5.5472684, dtype=float32), array(5.5472684, dtype=float32), array(0.50024414, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5410776, dtype=float32), array(0.50084406, dtype=float32)], d_loss_fake: [array(5.548163, dtype=float32), array(0.50024354, dtype=float32)]
# g_loss: [array(5.548163, dtype=float32), array(5.548163, dtype=float32), array(0.50024354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# d_loss_real: [array(5.541986, dtype=float32), array(0.5008421, dtype=float32)], d_loss_fake: [array(5.548904, dtype=float32), array(0.50024295, dtype=float32)]
# g_loss: [array(5.548904, dtype=float32), array(5.548904, dtype=float32), array(0.50024295, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# d_loss_real: [array(5.5427547, dtype=float32), array(0.50084007, dtype=float32)], d_loss_fake: [array(5.5496173, dtype=float32), array(0.5002424, dtype=float32)]
# g_loss: [array(5.5496173, dtype=float32), array(5.5496173, dtype=float32), array(0.5002424, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# d_loss_real: [array(5.5434895, dtype=float32), array(0.50083804, dtype=float32)], d_loss_fake: [array(5.5504475, dtype=float32), array(0.5002418, dtype=float32)]
# g_loss: [array(5.5504475, dtype=float32), array(5.5504475, dtype=float32), array(0.5002418, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.544306, dtype=float32), array(0.5008361, dtype=float32)], d_loss_fake: [array(5.5513473, dtype=float32), array(0.5002412, dtype=float32)]
# g_loss: [array(5.5513473, dtype=float32), array(5.5513473, dtype=float32), array(0.5002412, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.5452213, dtype=float32), array(0.50083405, dtype=float32)], d_loss_fake: [array(5.5524993, dtype=float32), array(0.5002407, dtype=float32)]
# g_loss: [array(5.5524993, dtype=float32), array(5.5524993, dtype=float32), array(0.5002407, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# d_loss_real: [array(5.5464096, dtype=float32), array(0.5008321, dtype=float32)], d_loss_fake: [array(5.5533357, dtype=float32), array(0.5002401, dtype=float32)]
# g_loss: [array(5.5533357, dtype=float32), array(5.5533357, dtype=float32), array(0.5002401, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(5.54725, dtype=float32), array(0.5008301, dtype=float32)], d_loss_fake: [array(5.554041, dtype=float32), array(0.50023955, dtype=float32)]
# g_loss: [array(5.554041, dtype=float32), array(5.554041, dtype=float32), array(0.50023955, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.5479608, dtype=float32), array(0.5008282, dtype=float32)], d_loss_fake: [array(5.5550013, dtype=float32), array(0.50023896, dtype=float32)]
# g_loss: [array(5.5550013, dtype=float32), array(5.5550013, dtype=float32), array(0.50023896, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.548939, dtype=float32), array(0.50082624, dtype=float32)], d_loss_fake: [array(5.5561547, dtype=float32), array(0.5002384, dtype=float32)]
# g_loss: [array(5.5561547, dtype=float32), array(5.5561547, dtype=float32), array(0.5002384, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.550101, dtype=float32), array(0.5008243, dtype=float32)], d_loss_fake: [array(5.5572486, dtype=float32), array(0.5002378, dtype=float32)]
# g_loss: [array(5.5572486, dtype=float32), array(5.5572486, dtype=float32), array(0.5002378, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# d_loss_real: [array(5.551225, dtype=float32), array(0.50080407, dtype=float32)], d_loss_fake: [array(5.5582905, dtype=float32), array(0.50021905, dtype=float32)]
# g_loss: [array(5.5582905, dtype=float32), array(5.5582905, dtype=float32), array(0.50021905, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.5522633, dtype=float32), array(0.5008022, dtype=float32)], d_loss_fake: [array(5.5594826, dtype=float32), array(0.5002185, dtype=float32)]
# g_loss: [array(5.5594826, dtype=float32), array(5.5594826, dtype=float32), array(0.5002185, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.5534706, dtype=float32), array(0.5008004, dtype=float32)], d_loss_fake: [array(5.560305, dtype=float32), array(0.50021803, dtype=float32)]
# g_loss: [array(5.560305, dtype=float32), array(5.560305, dtype=float32), array(0.50021803, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.554296, dtype=float32), array(0.50079846, dtype=float32)], d_loss_fake: [array(5.561331, dtype=float32), array(0.5002175, dtype=float32)]
# g_loss: [array(5.561331, dtype=float32), array(5.561331, dtype=float32), array(0.5002175, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5553474, dtype=float32), array(0.5007966, dtype=float32)], d_loss_fake: [array(5.562138, dtype=float32), array(0.500217, dtype=float32)]
# g_loss: [array(5.562138, dtype=float32), array(5.562138, dtype=float32), array(0.500217, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
# d_loss_real: [array(5.556148, dtype=float32), array(0.50079477, dtype=float32)], d_loss_fake: [array(5.563155, dtype=float32), array(0.5002165, dtype=float32)]
# g_loss: [array(5.563155, dtype=float32), array(5.563155, dtype=float32), array(0.5002165, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# d_loss_real: [array(5.557203, dtype=float32), array(0.500793, dtype=float32)], d_loss_fake: [array(5.564181, dtype=float32), array(0.500216, dtype=float32)]
# g_loss: [array(5.564181, dtype=float32), array(5.564181, dtype=float32), array(0.500216, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# d_loss_real: [array(5.5582385, dtype=float32), array(0.50079113, dtype=float32)], d_loss_fake: [array(5.5649886, dtype=float32), array(0.50021553, dtype=float32)]
# g_loss: [array(5.5649886, dtype=float32), array(5.5649886, dtype=float32), array(0.50021553, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# d_loss_real: [array(5.559057, dtype=float32), array(0.50078934, dtype=float32)], d_loss_fake: [array(5.5657806, dtype=float32), array(0.500215, dtype=float32)]
# g_loss: [array(5.5657806, dtype=float32), array(5.5657806, dtype=float32), array(0.500215, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5598655, dtype=float32), array(0.50075173, dtype=float32)], d_loss_fake: [array(5.566352, dtype=float32), array(0.50017875, dtype=float32)]
# g_loss: [array(5.566352, dtype=float32), array(5.566352, dtype=float32), array(0.50017875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.560425, dtype=float32), array(0.50075, dtype=float32)], d_loss_fake: [array(5.567199, dtype=float32), array(0.5001784, dtype=float32)]
# g_loss: [array(5.567199, dtype=float32), array(5.567199, dtype=float32), array(0.5001784, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.5612855, dtype=float32), array(0.5007483, dtype=float32)], d_loss_fake: [array(5.568094, dtype=float32), array(0.500178, dtype=float32)]
# g_loss: [array(5.568094, dtype=float32), array(5.568094, dtype=float32), array(0.500178, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.562203, dtype=float32), array(0.5007466, dtype=float32)], d_loss_fake: [array(5.5690284, dtype=float32), array(0.50017756, dtype=float32)]
# g_loss: [array(5.5690284, dtype=float32), array(5.5690284, dtype=float32), array(0.50017756, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.563152, dtype=float32), array(0.5007449, dtype=float32)], d_loss_fake: [array(5.570223, dtype=float32), array(0.50017715, dtype=float32)]
# g_loss: [array(5.570223, dtype=float32), array(5.570223, dtype=float32), array(0.50017715, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# d_loss_real: [array(5.5643625, dtype=float32), array(0.5007432, dtype=float32)], d_loss_fake: [array(5.5712643, dtype=float32), array(0.5001767, dtype=float32)]
# g_loss: [array(5.5712643, dtype=float32), array(5.5712643, dtype=float32), array(0.5001767, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# d_loss_real: [array(5.5654187, dtype=float32), array(0.50074154, dtype=float32)], d_loss_fake: [array(5.572085, dtype=float32), array(0.50017637, dtype=float32)]
# g_loss: [array(5.572085, dtype=float32), array(5.572085, dtype=float32), array(0.50017637, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# d_loss_real: [array(5.5662346, dtype=float32), array(0.5007399, dtype=float32)], d_loss_fake: [array(5.573105, dtype=float32), array(0.50017595, dtype=float32)]
# g_loss: [array(5.573105, dtype=float32), array(5.573105, dtype=float32), array(0.50017595, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# d_loss_real: [array(5.5672717, dtype=float32), array(0.5007382, dtype=float32)], d_loss_fake: [array(5.574164, dtype=float32), array(0.50017554, dtype=float32)]
# g_loss: [array(5.574164, dtype=float32), array(5.574164, dtype=float32), array(0.50017554, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# d_loss_real: [array(5.5683455, dtype=float32), array(0.50073653, dtype=float32)], d_loss_fake: [array(5.574718, dtype=float32), array(0.5001752, dtype=float32)]

# %% [markdown]
# # Image generation
# We generate sample images using the model.

# %%
def display_original_and_generated_images(generator, train_ds, num_images):
    # Get a batch of original images
    for original_images, _ in train_ds.take(1):  # Take one batch
        break

    # Generate images from the GAN
    noise = np.random.normal(0, 1, (num_images, latent_dim))  # Generate random noise
    generated_imgs = generator.predict(noise)
    generated_imgs = 0.5 * generated_imgs + 0.5  # Rescale to [0, 1]

    # Placeholder to store MSE values
    mse_values = []

    plt.figure(figsize=(20, 8))

    # # Display original images
    # for i in range(num_images):
    #     plt.subplot(2, num_images, i + 1)
    #     plt.imshow(original_images[i].numpy().astype("uint8"))  # Retain original colors
    #     plt.axis('off')
    #     plt.title("Original")

    # # Display generated images
    # for i in range(num_images):
    #     plt.subplot(2, num_images, num_images + i + 1)
    #     plt.imshow(generated_imgs[i])  # Display generated images in color
    #     plt.axis('off')
    #     plt.title("Generated")

    for i in range(num_images):
      # Original image
      original = original_images[i].numpy().reshape(30, 40, 3)  # Assuming x_test is the dataset
      # Reconstructed image
      reconstructed = generated_imgs[i].reshape(30, 40, 3)  # Assuming encoded_imgs are the reconstructions
      # Convert to grayscale
      original = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
      reconstructed = cv2.cvtColor(reconstructed, cv2.COLOR_BGR2GRAY)
      # Compute MSE
      mse = np.mean((original - reconstructed) ** 2)
      mse_values.append(mse)

      # Display Original Image
      ax = plt.subplot(3, num_images, i + 1)
      plt.imshow(original)
      plt.title(f"\nOriginal {i+1}")
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)

      # Display Reconstructed Image
      ax = plt.subplot(3, num_images, i + 1 + num_images)
      plt.imshow(reconstructed)
      plt.title(f"\nReconstructed {i+1}")
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)

      # Display MSE Value
      ax = plt.subplot(3, num_images, i + 1 + 2 * num_images)
      plt.text(0.5, 0.5, f"MSE: {mse:.4f}", fontsize=12, ha='center', va='center')
      plt.axis('off')


    # Adjust layout and show the plot
    plt.tight_layout()
    plt.show()

    # Print MSE values for reference
    for i, mse in enumerate(mse_values, 1):
        print(f"Image {i}: MSE = {mse:.4f}")

    # Compute the average MSE across all images
    average_mse = np.mean(mse_values)
    print(f"\nAverage MSE: {average_mse:.4f}")



# End timer
print(f"batch_size = {batch_size}")
print(f"epochs = {num_epochs}")
end_time = time.time()
elapsed_time = end_time - start_time
print(f"time = {elapsed_time:.2f} seconds")

# %%
# Get a batch of original images
for original_images, _ in train_ds.take(1):  # Take one batch
    break

display_original_and_generated_images(generator, train_ds, num_images=6)
